# %% [markdown]
# <a href="https://colab.research.google.com/github/HasibulHassan123/LabTask3/blob/main/labtask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
courses = []
choice = 'random'

def line():
    print('--------------------------------')

def show_menu():
    line()
    print('MENU')
    line()
    print('1. Add semester Course')
    print('2. Unenroll any course')
    print('3. View all courses')
    print('4. Exit programme')
    line()
    choice = input('Enter your choice: ')
    return choice

while choice != '4':
    choice = show_menu()
    if choice == '1':
        course = input('Add any course:')
        courses.append(course)
        print('Course', course,'Course Added successfully!')
    elif choice == '2':
        if courses != []:
          print('Courses List:')
          for course in courses:
              print('●', course)
          course = input('Choice which course you want to unenroll: ')
          if course in courses:
              courses.remove(course)
              print('Successfully Unenroll course', course)
          else:
              print('Not found course', course)
        else:
              print('No course yet!')
    elif choice == '3':
        if courses != []:
          print('List of courses:')
          for course in courses:
              print('●', courses)
        else:
              print('No course yet')
    elif choice == '4':
        print('Thank You')
    else:
        print('Please enter one of 1, 2, 3 or 4')
# Out:
# --------------------------------
# MENU
# --------------------------------
# 1. Add semester Course
# 2. Unenroll any course
# 3. View all courses
# 4. Exit programme
# --------------------------------
# Enter your choice: 1
# Add any course:CSE415
# Course CSE415 Course Added successfully!
# --------------------------------
# MENU
# --------------------------------
# 1. Add semester Course
# 2. Unenroll any course
# 3. View all courses
# 4. Exit programme
# --------------------------------
# Enter your choice: 1
# Add any course:CSE414
# Course CSE414 Course Added successfully!
# --------------------------------
# MENU
# --------------------------------
# 1. Add semester Course
# 2. Unenroll any course
# 3. View all courses
# 4. Exit programme
# --------------------------------
# Enter your choice: 1
# Add any course:CSE417
# Course CSE417 Course Added successfully!
# --------------------------------
# MENU
# --------------------------------
# 1. Add semester Course
# 2. Unenroll any course
# 3. View all courses
# 4. Exit programme
# --------------------------------
# Enter your choice: 2
# Courses List:
# ● CSE415
# ● CSE414
# ● CSE417
# Choice which course you want to unenroll: CSE415
# Successfully Unenroll course CSE415
# --------------------------------
# MENU
# --------------------------------
# 1. Add semester Course
# 2. Unenroll any course
# 3. View all courses
# 4. Exit programme
# --------------------------------
# Enter your choice: 3
# List of courses:
# ● ['CSE414', 'CSE417']
# ● ['CSE414', 'CSE417']
# --------------------------------
# MENU
# --------------------------------
# 1. Add semester Course
# 2. Unenroll any course
# 3. View all courses
# 4. Exit programme
# --------------------------------
# Enter your choice: 4
# Thank You
